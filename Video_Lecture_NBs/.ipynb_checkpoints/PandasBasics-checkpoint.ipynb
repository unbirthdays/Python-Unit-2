# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows = 20

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# 5           0       3    male   NaN      0      0   8.4583        Q  NaN
# 6           0       1    male  54.0      0      0  51.8625        S    E
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# ...

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN
# 5         0       3    male   NaN      0      0   8.4583        Q  NaN
# 6         0       1    male  54.0      0      0  51.8625        S    E
# 7         0       3    male   2.0      3      1  21.0750        S  NaN
# 8         1       3  female  27.0      0      2  11.1333        S  NaN
# 9         1       2  female  14.0      1      0  30.0708        C  NaN

# %%
titanic.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
# ...

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.tail(10)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# 882         0       3  female  22.0      0      0  10.5167        S  NaN
# 883         0       2    male  28.0      0      0  10.5000        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN

# %% [markdown]
# ## Data Inspection

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# 5           0       3    male   NaN      0      0   8.4583        Q  NaN
# 6           0       1    male  54.0      0      0  51.8625        S    E
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include = "O")
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %% [markdown]
# Capital O selects all columns where the datatype is an object

# %% [markdown]
# ## Built-in Functions, Attributes, and Methods with Pandas

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### DataFrame Attributes

# %%
len(titanic)
# Out:
# 891

# %% [markdown]
# len returns the number of rows in the dataframe

# %%
round(titanic, 0)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# 5           0       3    male   NaN      0      0   8.0        Q  NaN
# 6           0       1    male  54.0      0      0  52.0        S    E
# 7           0       3    male   2.0      3      1  21.0        S  NaN
# 8           1       3  female  27.0      0      2  11.0        S  NaN
# 9           1       2  female  14.0      1      0  30.0        C  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 881         0       3    male  33.0      0      0   8.0        S  NaN
# ...

# %%
min(titanic)
# Out:
# 'age'

# %% [markdown]
# min column label

# %%
titanic.shape
# Out:
# (891, 9)

# %% [markdown]
# 891 rows, 9 columns

# %%
titanic.size
# Out:
# 8019

# %% [markdown]
# all elements in dataframe (rows*columns)

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %% [markdown]
# shows range of dataframe

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %% [markdown]
# shows the columns and types

# %% [markdown]
# ### Dataframe Methods

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.min()
# Out:
# /var/folders/_j/fzbq3gvn0cx_99l539dvts7h0000gp/T/ipykernel_3616/3376850614.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic.min()
# survived         0
# pclass           1
# sex         female
# age           0.42
# sibsp            0
# parch            0
# fare           0.0
# dtype: object

# %% [markdown]
# ### Method Chaining

# %%
titanic.mean()
# Out:
# /var/folders/_j/fzbq3gvn0cx_99l539dvts7h0000gp/T/ipykernel_3616/929819788.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic.mean()
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %%
titanic.mean().sort_values()
# Out:
# /var/folders/_j/fzbq3gvn0cx_99l539dvts7h0000gp/T/ipykernel_3616/3254614695.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   titanic.mean().sort_values()
# parch        0.381594
# survived     0.383838
# sibsp        0.523008
# pclass       2.308642
# age         29.699118
# fare        32.204208
# dtype: float64
