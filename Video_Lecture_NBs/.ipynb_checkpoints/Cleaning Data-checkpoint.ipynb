# %% [markdown]
# # Cleaning Data

# %% [markdown]
# ## First Inspection / Handling Inconsistent Data

# %%
import pandas as pd

# %% [markdown]
# ### Titanic Dataset

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic[["survived", "sex", "age", "fare"]].describe()
# Out:
#          survived         age        fare
# count  891.000000  714.000000  891.000000
# mean     0.383838   29.699118   32.204208
# std      0.486592   14.526497   49.693429
# min      0.000000    0.420000    0.000000
# 25%      0.000000   20.125000    7.910400
# 50%      0.000000   28.000000   14.454200
# 75%      1.000000   38.000000   31.000000
# max      1.000000   80.000000  512.329200

# %%
titanic.survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
titanic.survived.replace(to_replace= [0, 1], value = ["no", "yes"], inplace = True)

# %%
titanic.survived.value_counts()
# Out:
# no     549
# yes    342
# Name: survived, dtype: int64

# %%
titanic.rename(columns = {"sex": "gender"}, inplace = True)

# %%
titanic.head()
# Out:
#   survived  pclass  gender   age  sibsp  parch     fare embarked deck
# 0       no       3    male  22.0      1      0   7.2500        S  NaN
# 1      yes       1  female  38.0      1      0  71.2833        C    C
# 2      yes       3  female  26.0      0      0   7.9250        S  NaN
# 3      yes       1  female  35.0      1      0  53.1000        S    C
# 4       no       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.iloc[:, 1:].describe()
# Out:
#            pclass         age       sibsp       parch        fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ## String Operations

# %%
titanic.head()
# Out:
#   survived  pclass  gender   age  sibsp  parch     fare embarked deck
# 0       no       3    male  22.0      1      0   7.2500        S  NaN
# 1      yes       1  female  38.0      1      0  71.2833        C    C
# 2      yes       3  female  26.0      0      0   7.9250        S  NaN
# 3      yes       1  female  35.0      1      0  53.1000        S    C
# 4       no       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    int64
#  2   gender    891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 62.8+ KB

# %%
pd.to_numeric(titanic.fare)
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %%
titanic.deck.str.replace("$", "")
# Out:
# /var/folders/_j/fzbq3gvn0cx_99l539dvts7h0000gp/T/ipykernel_48607/3705158596.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   titanic.deck.str.replace("$", "")
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: deck, Length: 891, dtype: object

# %%
summer = pd.read_csv("summer.csv")

# %%
summer.head(20)
# Out:
#     Year    City      Sport Discipline                Athlete Country Gender  \
# 0   1896  Athens   Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 1   1896  Athens   Aquatics   Swimming       HERSCHMANN, Otto     AUT    Men
# 2   1896  Athens   Aquatics   Swimming      DRIVAS, Dimitrios     GRE    Men
# 3   1896  Athens   Aquatics   Swimming     MALOKINIS, Ioannis     GRE    Men
# 4   1896  Athens   Aquatics   Swimming     CHASAPIS, Spiridon     GRE    Men
# 5   1896  Athens   Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 6   1896  Athens   Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 7   1896  Athens   Aquatics   Swimming       ANDREOU, Joannis     GRE    Men
# 8   1896  Athens   Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 9   1896  Athens   Aquatics   Swimming          NEUMANN, Paul     AUT    Men
# 10  1896  Athens   Aquatics   Swimming      PEPANOS, Antonios     GRE    Men
# 11  1896  Athens  Athletics  Athletics          LANE, Francis     USA    Men
# 12  1896  Athens  Athletics  Athletics       SZOKOLYI, Alajos     HUN    Men
# 13  1896  Athens  Athletics  Athletics          BURKE, Thomas     USA    Men
# 14  1896  Athens  Athletics  Athletics         HOFMANN, Fritz     GER    Men
# 15  1896  Athens  Athletics  Athletics         CURTIS, Thomas     USA    Men
# 16  1896  Athens  Athletics  Athletics     GOULDING, Grantley     GBR    Men
# 17  1896  Athens  Athletics  Athletics      LERMUSIAUX, Albin     FRA    Men
# 18  1896  Athens  Athletics  Athletics           FLACK, Edwin     AUS    Men
# 19  1896  Athens  Athletics  Athletics          BLAKE, Arthur     USA    Men
#
#                          Event   Medal
# 0               100M Freestyle    Gold
# 1               100M Freestyle  Silver
# 2   100M Freestyle For Sailors  Bronze
# 3   100M Freestyle For Sailors    Gold
# 4   100M Freestyle For Sailors  Silver
# 5              1200M Freestyle  Bronze
# 6              1200M Freestyle    Gold
# 7              1200M Freestyle  Silver
# 8               400M Freestyle  Bronze
# 9               400M Freestyle    Gold
# 10              400M Freestyle  Silver
# 11                        100M  Bronze
# 12                        100M  Bronze
# 13                        100M    Gold
# 14                        100M  Silver
# 15                110M Hurdles    Gold
# 16                110M Hurdles  Silver
# 17                       1500M  Bronze
# 18                       1500M    Gold
# 19                       1500M  Silver

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.Athlete = summer.Athlete.str.title()
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  Hajos, Alfred     HUN    Men              100M Freestyle
# 1               Herschmann, Otto     AUT    Men              100M Freestyle
# 2              Drivas, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             Malokinis, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             Chasapis, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         Janikowski, Damian     POL    Men                    Wg 84 KG
# 31161  Rezaei, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             Totrov, Rustam     RUS    Men                    Wg 96 KG
# 31163          Aleksanyan, Artur     ARM    Men                    Wg 96 KG
# 31164             Lidberg, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
summer.loc[summer.Athlete == "Hajos, Alfred"]
# Out:
#    Year    City     Sport Discipline        Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming  Hajos, Alfred     HUN    Men
# 6  1896  Athens  Aquatics   Swimming  Hajos, Alfred     HUN    Men
#
#              Event Medal
# 0   100M Freestyle  Gold
# 6  1200M Freestyle  Gold

# %%
summer.iloc[0, 4]
# Out:
# 'Hajos, Alfred'

# %%
summer.Athlete.str.strip()
# Out:
# 0                    Hajos, Alfred
# 1                 Herschmann, Otto
# 2                Drivas, Dimitrios
# 3               Malokinis, Ioannis
# 4               Chasapis, Spiridon
#                    ...
# 31160           Janikowski, Damian
# 31161    Rezaei, Ghasem Gholamreza
# 31162               Totrov, Rustam
# 31163            Aleksanyan, Artur
# 31164               Lidberg, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %% [markdown]
# removes whitespace

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    object
#  1   pclass    891 non-null    int64
#  2   gender    891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 62.8+ KB

# %%
titanic.survived.replace(to_replace= ["no", "yes"], value = [0, 1], inplace = True)

# %%
titanic
# Out:
#      survived  pclass  gender   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.fare.astype("float")
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: fare, Length: 891, dtype: float64

# %% [markdown]
# changes datatype to whatever

# %%
titanic["fare"] = titanic.fare.astype("float")

# %%
titanic["survived"] = titanic.survived.astype("int")

# %% [markdown]
# ## Intro to NA Values

# %%
import numpy as np

# %%
sales = pd.read_csv("sales.csv", index_col = 0)

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Steven to Paul
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mon     4 non-null      int64
#  1   Tue     4 non-null      int64
#  2   Wed     4 non-null      int64
#  3   Thu     3 non-null      float64
#  4   Fri     4 non-null      int64
# dtypes: float64(1), int64(4)
# memory usage: 192.0+ bytes

# %%
sales.loc["Steven", "Thu"]
# Out:
# nan

# %%
# sales.iloc[1,1] = None   
# this can produce missing values manually

# %%
# sales.iloc[2,2] = np.nan
# this can as well

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Steven to Paul
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mon     4 non-null      int64
#  1   Tue     4 non-null      int64
#  2   Wed     4 non-null      int64
#  3   Thu     3 non-null      float64
#  4   Fri     4 non-null      int64
# dtypes: float64(1), int64(4)
# memory usage: 364.0+ bytes

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu  Fri
# Steven   34   27   15   NaN   33
# Mike     45    9   74  87.0   12
# Andi     17   33   54   8.0   29
# Paul     87   67   27  45.0    7

# %%
sales.iloc[0,3] = 0

# %%
sales.Thu = sales.Thu.astype("int")

# %%
sales
# Out:
#         Mon  Tue  Wed  Thu  Fri
# Steven   34   27   15    0   33
# Mike     45    9   74   87   12
# Andi     17   33   54    8   29
# Paul     87   67   27   45    7

# %% [markdown]
# ## Detecting Missing Values

# %%
titanic
# Out:
#      survived  pclass  gender   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   gender    891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.isna()
# Out:
#      survived  pclass  gender    age  sibsp  parch   fare  embarked   deck
# 0       False   False   False  False  False  False  False     False   True
# 1       False   False   False  False  False  False  False     False  False
# 2       False   False   False  False  False  False  False     False   True
# 3       False   False   False  False  False  False  False     False  False
# 4       False   False   False  False  False  False  False     False   True
# ..        ...     ...     ...    ...    ...    ...    ...       ...    ...
# 886     False   False   False  False  False  False  False     False   True
# 887     False   False   False  False  False  False  False     False  False
# 888     False   False   False   True  False  False  False     False   True
# 889     False   False   False  False  False  False  False     False  False
# 890     False   False   False  False  False  False  False     False   True
#
# [891 rows x 9 columns]

# %%
titanic.isna().sum(axis = 0)
# Out:
# survived      0
# pclass        0
# gender        0
# age         177
# sibsp         0
# parch         0
# fare          0
# embarked      2
# deck        688
# dtype: int64

# %%
titanic.isna().any(axis = 0)
# Out:
# survived    False
# pclass      False
# gender      False
# age          True
# sibsp       False
# parch       False
# fare        False
# embarked     True
# deck         True
# dtype: bool

# %%
titanic[titanic.isna().any(axis = 1)]
# Out:
#      survived  pclass  gender   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# 5           0       3    male   NaN      0      0   8.4583        Q  NaN
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 885         0       3  female  39.0      0      5  29.1250        Q  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [709 rows x 9 columns]

# %%
titanic.notna()
# Out:
#      survived  pclass  gender    age  sibsp  parch  fare  embarked   deck
# 0        True    True    True   True   True   True  True      True  False
# 1        True    True    True   True   True   True  True      True   True
# 2        True    True    True   True   True   True  True      True  False
# 3        True    True    True   True   True   True  True      True   True
# 4        True    True    True   True   True   True  True      True  False
# ..        ...     ...     ...    ...    ...    ...   ...       ...    ...
# 886      True    True    True   True   True   True  True      True  False
# 887      True    True    True   True   True   True  True      True   True
# 888      True    True    True  False   True   True  True      True  False
# 889      True    True    True   True   True   True  True      True   True
# 890      True    True    True   True   True   True  True      True  False
#
# [891 rows x 9 columns]

# %%
titanic.notna().sum(axis = 0)
# Out:
# survived    891
# pclass      891
# gender      891
# age         714
# sibsp       891
# parch       891
# fare        891
# embarked    889
# deck        203
# dtype: int64

# %%
titanic.notna().all(axis = 0)
# Out:
# survived     True
# pclass       True
# gender       True
# age         False
# sibsp        True
# parch        True
# fare         True
# embarked    False
# deck        False
# dtype: bool

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (12, 8))
sns.heatmap(titanic.notna())
plt.show()

# %%
titanic.age.value_counts(dropna = False)
# Out:
# NaN      177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: age, Length: 89, dtype: int64

# %% [markdown]
# ## Removing Missing Values with dropna()

# %%
titanic.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   gender    891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic[titanic.embarked.isna()]
# Out:
#      survived  pclass  gender   age  sibsp  parch  fare embarked deck
# 61          1       1  female  38.0      0      0  80.0      NaN    B
# 829         1       1  female  62.0      0      0  80.0      NaN    B

# %%
titanic.age.value_counts(dropna = False)
# Out:
# NaN      177
# 24.00     30
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 36.50      1
# 55.50      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: age, Length: 89, dtype: int64

# %%
titanic.age.mean(skipna = True)
# Out:
# 29.69911764705882

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.dropna().shape
# Out:
# (182, 9)

# %% [markdown]
# dropping all entries with missing data leaves us with 182 entries. that is too low.

# %%
titanic.dropna(axis = 0, how = "any").shape
# Out:
# (182, 9)

# %% [markdown]
# rows with ANY missing value leaves us with 182 entries

# %%
titanic.dropna(axis = 1, how = "any").shape
# Out:
# (891, 6)

# %% [markdown]
# dropping columns that have any missing values leaves us with 6 columns

# %%
titanic.dropna(axis = 0, how = "all").shape
# Out:
# (891, 9)

# %% [markdown]
# dropping values with ALL missing values leaves us with the original 891

# %% [markdown]
# this means that no entries are fully empty

# %%
titanic.dropna(axis = 1, how = "all").shape
# Out:
# (891, 9)

# %% [markdown]
# same for columns

# %%
titanic.dropna(axis = 0, thresh = 8).shape
# Out:
# (733, 9)

# %% [markdown]
# dropping all rows with less than 8 non null values

# %%
titanic.dropna(axis = 1, thresh = 500).shape
# Out:
# (891, 8)

# %% [markdown]
# dropping all columns with less than 500 non null values

# %% [markdown]
# dropped the deck column

# %%
titanic.dropna(axis = 1, thresh = 500, inplace = True)

# %%
titanic.head()
# Out:
#    survived  pclass  gender   age  sibsp  parch     fare embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
titanic.shape
# Out:
# (891, 8)

# %%
titanic.dropna(axis = 0, subset = ["survived", "pclass", "gender", "age"], thresh = 4).shape
# Out:
# (714, 8)

# %% [markdown]
# dropping all rows that do not have at least 4 (aka all) of the subset values

# %%
titanic.dropna(axis = 0, subset = ["survived", "pclass", "gender", "age"], how = "any").shape
# Out:
# (714, 8)

# %% [markdown]
# another way to say this

# %% [markdown]
# ## Replacing Missing Values

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
# 12         0       3    male  20.0      0      0   8.0500        S  NaN
# 13         0       3    male  39.0      1      5  31.2750        S  NaN
# 14         0       3  female  14.0      0      0   7.8542        S  NaN
# 15         1       2  female  55.0      0      0  16.0000        S  NaN
# 16         0       3    male   2.0      4      1  29.1250        Q  NaN
# 17         1       2    male   NaN      0      0  13.0000        S  NaN
# 18         0       3  female  31.0      1      0  18.0000        S  NaN
# 19         1       3  female   NaN      0      0   7.2250        C  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic[titanic.age.isna()]
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked deck
# 5           0       3    male  NaN      0      0   8.4583        Q  NaN
# 17          1       2    male  NaN      0      0  13.0000        S  NaN
# 19          1       3  female  NaN      0      0   7.2250        C  NaN
# 26          0       3    male  NaN      0      0   7.2250        C  NaN
# 28          1       3  female  NaN      0      0   7.8792        Q  NaN
# ..        ...     ...     ...  ...    ...    ...      ...      ...  ...
# 859         0       3    male  NaN      0      0   7.2292        C  NaN
# 863         0       3  female  NaN      8      2  69.5500        S  NaN
# 868         0       3    male  NaN      0      0   9.5000        S  NaN
# 878         0       3    male  NaN      0      0   7.8958        S  NaN
# 888         0       3  female  NaN      1      2  23.4500        S  NaN
#
# [177 rows x 9 columns]

# %%
titanic.age.mean()
# Out:
# 29.69911764705882

# %%
mean = round(titanic.age.mean(), 1)
mean
# Out:
# 29.7

# %%
titanic.age.fillna(mean, inplace = True)

# %%
titanic.head(20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male  29.7      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
# 12         0       3    male  20.0      0      0   8.0500        S  NaN
# 13         0       3    male  39.0      1      5  31.2750        S  NaN
# 14         0       3  female  14.0      0      0   7.8542        S  NaN
# 15         1       2  female  55.0      0      0  16.0000        S  NaN
# 16         0       3    male   2.0      4      1  29.1250        Q  NaN
# 17         1       2    male  29.7      0      0  13.0000        S  NaN
# 18         0       3  female  31.0      1      0  18.0000        S  NaN
# 19         1       3  female  29.7      0      0   7.2250        C  NaN

# %% [markdown]
# this fills all null values with the mean

# %% [markdown]
# ## Detection of Duplicates

# %%
alphabet = pd.DataFrame(["a", "b", "c", "c", "d", "e", "f", "g", "g", "g"], columns = ["Alphabet"])

# %%
alphabet
# Out:
#   Alphabet
# 0        a
# 1        b
# 2        c
# 3        c
# 4        d
# 5        e
# 6        f
# 7        g
# 8        g
# 9        g

# %%
alphabet.duplicated(keep = False)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
alphabet[alphabet.duplicated(keep = False)]
# Out:
#   Alphabet
# 2        c
# 3        c
# 7        g
# 8        g
# 9        g

# %%
alphabet.duplicated(keep = "first")
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8     True
# 9     True
# dtype: bool

# %%
alphabet[alphabet.duplicated(keep = "first")]
# Out:
#   Alphabet
# 3        c
# 8        g
# 9        g

# %%
titanic.duplicated(keep = "first", subset = ["survived", "pclass"]).sum()
# Out:
# 885

# %%
titanic[titanic.duplicated(keep = False)].head(20)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# 26          0       3    male  29.7      0      0   7.2250        C  NaN
# 28          1       3  female  29.7      0      0   7.8792        Q  NaN
# 29          0       3    male  29.7      0      0   7.8958        S  NaN
# 32          1       3  female  29.7      0      0   7.7500        Q  NaN
# 37          0       3    male  21.0      0      0   8.0500        S  NaN
# 42          0       3    male  29.7      0      0   7.8958        C  NaN
# 45          0       3    male  29.7      0      0   8.0500        S  NaN
# 46          0       3    male  29.7      1      0  15.5000        Q  NaN
# 47          1       3  female  29.7      0      0   7.7500        Q  NaN
# 53          1       2  female  29.0      1      0  26.0000        S  NaN
# 64          0       1    male  29.7      0      0  27.7208        C  NaN
# 65          1       3    male  29.7      1      1  15.2458        C  NaN
# 74          1       3    male  32.0      0      0  56.4958        S  NaN
# 76          0       3    male  29.7      0      0   7.8958        S  NaN
# 77          0       3    male  29.7      0      0   8.0500        S  NaN
# 87          0       3    male  29.7      0      0   8.0500        S  NaN
# 91          0       3    male  20.0      0      0   7.8542        S  NaN
# 95          0       3    male  29.7      0      0   8.0500        S  NaN
# 101         0       3    male  29.7      0      0   7.8958        S  NaN

# %%
summer = pd.read_csv("summer.csv")

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 4             CHASAPIS, Spiridon     GRE    Men  100M Freestyle For Sailors
# ...                          ...     ...    ...                         ...
# 31160         JANIKOWSKI, Damian     POL    Men                    Wg 84 KG
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men                    Wg 96 KG
# 31162             TOTROV, Rustam     RUS    Men                    Wg 96 KG
# 31163          ALEKSANYAN, Artur     ARM    Men                    Wg 96 KG
# 31164             LIDBERG, Jimmy     SWE    Men                    Wg 96 KG
#
#         Medal
# 0        Gold
# 1      Silver
# 2      Bronze
# 3        Gold
# 4      Silver
# ...       ...
# 31160  Bronze
# 31161    Gold
# 31162  Silver
# 31163  Bronze
# 31164  Bronze
#
# [31165 rows x 9 columns]

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.duplicated(keep = "first").sum()
# Out:
# 2

# %%
summer[summer.duplicated(keep = False)]
# Out:
#        Year    City      Sport Discipline       Athlete Country Gender  \
# 16098  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 16099  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 29779  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
# 29785  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
#
#          Event Medal
# 16098   Hockey  Gold
# 16099   Hockey  Gold
# 29779  Doubles  Gold
# 29785  Doubles  Gold

# %% [markdown]
#  ## Handling/Removing Duplicates

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female  29.7      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.duplicated().sum()
# Out:
# 107

# %%
titanic[titanic.duplicated()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 47          1       3  female  29.7      0      0   7.7500        Q  NaN
# 76          0       3    male  29.7      0      0   7.8958        S  NaN
# 77          0       3    male  29.7      0      0   8.0500        S  NaN
# 87          0       3    male  29.7      0      0   8.0500        S  NaN
# 95          0       3    male  29.7      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 870         0       3    male  26.0      0      0   7.8958        S  NaN
# 877         0       3    male  19.0      0      0   7.8958        S  NaN
# 878         0       3    male  29.7      0      0   7.8958        S  NaN
# 884         0       3    male  25.0      0      0   7.0500        S  NaN
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
#
# [107 rows x 9 columns]

# %%
# titanic.drop(index = [LIST # WHERE YOU WANT TO DROP], inplace = True)

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer[summer.duplicated(keep = False)]
# Out:
#        Year    City      Sport Discipline       Athlete Country Gender  \
# 16098  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 16099  1980  Moscow     Hockey     Hockey  SINGH, Singh     IND    Men
# 29779  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
# 29785  2012  London  Badminton  Badminton  ZHAO, Yunlei     CHN  Women
#
#          Event Medal
# 16098   Hockey  Gold
# 16099   Hockey  Gold
# 29779  Doubles  Gold
# 29785  Doubles  Gold

# %%
summer.drop(index = [16099, 29785], inplace = True)

# %%
summer[summer.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete, Country, Gender, Event, Medal]
# Index: []

# %% [markdown]
# removed duplicates, in reality these weren't duplicates but this is an example of how to remove them

# %%
alphabet[alphabet.duplicated(keep = False)]
# Out:
#   Alphabet
# 2        c
# 3        c
# 7        g
# 8        g
# 9        g

# %%
alphabet.drop_duplicates(inplace = True)

# %%
alphabet[alphabet.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [Alphabet]
# Index: []

# %%
alphabet
# Out:
#   Alphabet
# 0        a
# 1        b
# 2        c
# 4        d
# 5        e
# 6        f
# 7        g

# %% [markdown]
# ## ignore_index Parameter

# %%
alphabet = pd.DataFrame(["a", "b", "c", "c", "d", "e", "f", "g", "g", "g"], columns = ["Alphabet"])

# %%
alphabet
# Out:
#   Alphabet
# 0        a
# 1        b
# 2        c
# 3        c
# 4        d
# 5        e
# 6        f
# 7        g
# 8        g
# 9        g

# %%
alphabet.drop_duplicates()
# Out:
#   Alphabet
# 0        a
# 1        b
# 2        c
# 4        d
# 5        e
# 6        f
# 7        g

# %% [markdown]
# index is not a range index anymore

# %%
alphabet.drop_duplicates().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7 entries, 0 to 7
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Alphabet  7 non-null      object
# dtypes: object(1)
# memory usage: 112.0+ bytes

# %%
alphabet.drop_duplicates(ignore_index = True)
# Out:
#   Alphabet
# 0        a
# 1        b
# 2        c
# 3        d
# 4        e
# 5        f
# 6        g

# %%
alphabet.drop_duplicates(ignore_index = True).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Alphabet  7 non-null      object
# dtypes: object(1)
# memory usage: 184.0+ bytes

# %% [markdown]
# restores index

# %% [markdown]
# ## Detection of Outliers

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699293    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.700000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
plt.figure(figsize = (12,6))
titanic.boxplot("age")
plt.show()

# %%
plt.figure(figsize = (12, 6))
titanic.age.plot()
plt.show()

# %%
titanic.age.sort_values(ascending = False)
# Out:
# 630    80.00
# 851    74.00
# 96     71.00
# 493    71.00
# 116    70.50
#        ...
# 831     0.83
# 469     0.75
# 644     0.75
# 755     0.67
# 803     0.42
# Name: age, Length: 891, dtype: float64

# %%
titanic.loc[titanic.age > 90]
# Out:
# Empty DataFrame
# Columns: [survived, pclass, sex, age, sibsp, parch, fare, embarked, deck]
# Index: []

# %%
titanic.fare.sort_values(ascending = False)
# Out:
# 258    512.3292
# 737    512.3292
# 679    512.3292
# 88     263.0000
# 27     263.0000
#          ...
# 633      0.0000
# 413      0.0000
# 822      0.0000
# 732      0.0000
# 674      0.0000
# Name: fare, Length: 891, dtype: float64

# %%
plt.figure(figsize = (12, 6))
titanic.fare.plot()
plt.show()

# %%
titanic.loc[titanic.fare > 400]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 737         1       1    male  35.0      0      0  512.3292        C    B

# %% [markdown]
# ## Handling/Removing Outliers

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.loc[titanic.fare > 400]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 258         1       1  female  35.0      0      0  512.3292        C  NaN
# 679         1       1    male  36.0      0      1  512.3292        C    B
# 737         1       1    male  35.0      0      0  512.3292        C    B

# %%
index_out1 = titanic.loc[titanic.fare > 400].index

# %%
index_out1
# Out:
# Int64Index([258, 679, 737], dtype='int64')

# %%
titanic.loc[titanic.fare > 400, "fare"] = titanic.loc[titanic.fare > 400, "fare"]/10

# %% [markdown]
# let's pretend that the price was manually put in by 10x the original amount so we manipulated it to be / 10

# %%
titanic.loc[index_out1]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked deck
# 258         1       1  female  35.0      0      0  51.23292        C  NaN
# 679         1       1    male  36.0      0      1  51.23292        C    B
# 737         1       1    male  35.0      0      0  51.23292        C    B

# %%
titanic.loc[258, "fare"] = titanic.loc[258, "fare"].round(2)

# %%
titanic.loc[258]
# Out:
# survived         1
# pclass           1
# sex         female
# age           35.0
# sibsp            0
# parch            0
# fare         51.23
# embarked         C
# deck           NaN
# Name: 258, dtype: object

# %%
titanic.loc[679, "fare"] = titanic.loc[679, "fare"].round(2)

# %%
titanic.loc[737, "fare"] = titanic.loc[737, "fare"].round(2)

# %%
plt.figure(figsize = (12, 6))
titanic.fare.plot()
plt.show()

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699293    0.523008    0.381594   30.651685
# std      0.486592    0.836071   13.002015    1.102743    0.806057   41.124327
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.700000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  263.000000

# %% [markdown]
# keep in mind this is all fake manipulation, these are fake errors

# %% [markdown]
# ## Categorical Data

# %%
titanic.to_csv("titanic.csv", index = False)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       891 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.nunique()
# Out:
# survived      2
# pclass        3
# sex           2
# age          89
# sibsp         7
# parch         7
# fare        248
# embarked      3
# deck          7
# dtype: int64

# %%
titanic[["sex", "embarked"]].describe()
# Out:
#          sex embarked
# count    891      889
# unique     2        3
# top     male        S
# freq     577      644

# %%
titanic.sex = titanic.sex.astype("category")

# %%
titanic.embarked = titanic.embarked.astype("category")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    category
#  3   age       891 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    category
#  8   deck      203 non-null    object
# dtypes: category(2), float64(2), int64(4), object(1)
# memory usage: 50.8+ KB

# %% [markdown]
# changed dtypes to categories

# %%
summer.to_csv("summer.csv", index = False)

# %%
summer.describe(include = ["O"])
# Out:
#           City     Sport Discipline          Athlete Country Gender     Event  \
# count    31163     31163      31163            31163   31159  31163     31163
# unique      22        43         67            22762     147      2       666
# top     London  Aquatics  Athletics  PHELPS, Michael     USA    Men  Football
# freq      3566      4170       3638               22    4585  22745      1497
#
#         Medal
# count   31163
# unique      3
# top      Gold
# freq    10484

# %%
summer.nunique()
# Out:
# Year             27
# City             22
# Sport            43
# Discipline       67
# Athlete       22762
# Country         147
# Gender            2
# Event           666
# Medal             3
# dtype: int64

# %% [markdown]
# changing some columns to categories can save memory usage

# %% [markdown]
# ## New DataTypes and pd.NA in Pandas V1.0

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female  29.7      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       891 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic = titanic.convert_dtypes()

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    Int64
#  1   pclass    891 non-null    Int64
#  2   sex       891 non-null    string
#  3   age       891 non-null    Float64
#  4   sibsp     891 non-null    Int64
#  5   parch     891 non-null    Int64
#  6   fare      891 non-null    Float64
#  7   embarked  889 non-null    string
#  8   deck      203 non-null    string
# dtypes: Float64(2), Int64(4), string(3)
# memory usage: 68.0 KB

# %% [markdown]
# datatypes are changed to Int64, string, Float64

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  deck
# 0           0       3    male  22.0      1      0     7.25        S  <NA>
# 1           1       1  female  38.0      1      0  71.2833        C     C
# 2           1       3  female  26.0      0      0    7.925        S  <NA>
# 3           1       1  female  35.0      1      0     53.1        S     C
# 4           0       3    male  35.0      0      0     8.05        S  <NA>
# ..        ...     ...     ...   ...    ...    ...      ...      ...   ...
# 886         0       2    male  27.0      0      0     13.0        S  <NA>
# 887         1       1  female  19.0      0      0     30.0        S     B
# 888         0       3  female  29.7      1      2    23.45        S  <NA>
# 889         1       1    male  26.0      0      0     30.0        C     C
# 890         0       3    male  32.0      0      0     7.75        Q  <NA>
#
# [891 rows x 9 columns]

# %% [markdown]
# missing values will look different

# %%
titanic.iloc[0, -1]

# %%
type(titanic.iloc[0, -1])
# Out:
# pandas._libs.missing.NAType

# %%
pd.NA

# %% [markdown]
# these are new data types!
