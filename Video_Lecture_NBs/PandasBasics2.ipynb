# %%
import pandas as pd

# %%
summer = pd.read_csv("summer.csv")

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Athlete        HAJOS, Alfred
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: 0, dtype: object

# %% [markdown]
# iloc used for position based indexing

# %%
type(summer.iloc[0])
# Out:
# pandas.core.series.Series

# %%
summer.iloc[1]
# Out:
# Year                      1896
# City                    Athens
# Sport                 Aquatics
# Discipline            Swimming
# Athlete       HERSCHMANN, Otto
# Country                    AUT
# Gender                     Men
# Event           100M Freestyle
# Medal                   Silver
# Name: 1, dtype: object

# %%
summer.iloc[-1]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Athlete            LIDBERG, Jimmy
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: 31164, dtype: object

# %%
summer.iloc[[1, 2, 3]]
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
#
#                         Event   Medal
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold

# %%
summer.iloc[1:4]
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
#
#                         Event   Medal
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold

# %%
summer.iloc[0:4]
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold

# %%
summer.iloc[-5:]
# Out:
#        Year    City      Sport           Discipline  \
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender     Event   Medal
# 31160         JANIKOWSKI, Damian     POL    Men  Wg 84 KG  Bronze
# 31161  REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# 31162             TOTROV, Rustam     RUS    Men  Wg 96 KG  Silver
# 31163          ALEKSANYAN, Artur     ARM    Men  Wg 96 KG  Bronze
# 31164             LIDBERG, Jimmy     SWE    Men  Wg 96 KG  Bronze

# %%
summer.iloc[:]
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.iloc[[2, 45, 5467]]
# Out:
#       Year       City       Sport   Discipline            Athlete Country  \
# 2     1896     Athens    Aquatics     Swimming  DRIVAS, Dimitrios     GRE
# 45    1896     Athens   Athletics    Athletics  PERSAKIS, Ioannis     GRE
# 5467  1928  Amsterdam  Gymnastics  Artistic G.         POLAK, Ans     NED
#
#      Gender                       Event   Medal
# 2       Men  100M Freestyle For Sailors  Bronze
# 45      Men                 Triple Jump  Bronze
# 5467  Women            Team Competition    Gold

# %%
summer.head(10)
# Out:
#    Year    City     Sport Discipline                Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming       HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming      DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming     MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming     CHASAPIS, Spiridon     GRE    Men
# 5  1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 6  1896  Athens  Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 7  1896  Athens  Aquatics   Swimming       ANDREOU, Joannis     GRE    Men
# 8  1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
# 9  1896  Athens  Aquatics   Swimming          NEUMANN, Paul     AUT    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# ...

# %%
summer.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Athlete        HAJOS, Alfred
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: 0, dtype: object

# %%
summer.iloc[0,5]
# Out:
# 'HUN'

# %%
summer.iloc[[0, 5]]
# Out:
#    Year    City     Sport Discipline                Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming          HAJOS, Alfred     HUN    Men
# 5  1896  Athens  Aquatics   Swimming  CHOROPHAS, Efstathios     GRE    Men
#
#              Event   Medal
# 0   100M Freestyle    Gold
# 5  1200M Freestyle  Bronze

# %%
summer.iloc[0, :3]
# Out:
# Year         1896
# City       Athens
# Sport    Aquatics
# Name: 0, dtype: object

# %%
summer.iloc[0, [1, 3, 6, 8]]
# Out:
# City            Athens
# Discipline    Swimming
# Gender             Men
# Medal             Gold
# Name: 0, dtype: object

# %%
summer.iloc[34:39, [1, 3, 6, 8]]
# Out:
#       City Discipline Gender   Medal
# 34  Athens  Athletics    Men  Silver
# 35  Athens  Athletics    Men  Bronze
# 36  Athens  Athletics    Men    Gold
# 37  Athens  Athletics    Men  Silver
# 38  Athens  Athletics    Men  Bronze

# %%
summer.iloc[:, 4]
# Out:
# 0                    HAJOS, Alfred
# 1                 HERSCHMANN, Otto
# 2                DRIVAS, Dimitrios
# 3               MALOKINIS, Ioannis
# 4               CHASAPIS, Spiridon
#                    ...
# 31160           JANIKOWSKI, Damian
# 31161    REZAEI, Ghasem Gholamreza
# 31162               TOTROV, Rustam
# 31163            ALEKSANYAN, Artur
# 31164               LIDBERG, Jimmy
# Name: Athlete, Length: 31165, dtype: object

# %%
summer.iloc[:, 5].equals(summer.Country)
# Out:
# True

# %%
summer["Country"]
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 31160    POL
# 31161    IRI
# 31162    RUS
# 31163    ARM
# 31164    SWE
# Name: Country, Length: 31165, dtype: object

# %%
summer.iloc[2]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Athlete                DRIVAS, Dimitrios
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: 2, dtype: object

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
summer.loc[4]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Athlete               CHASAPIS, Spiridon
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Silver
# Name: 4, dtype: object

# %%
summer = pd.read_csv("summer.csv", index_col="Athlete")

# %%
summer.loc["DRIVAS, Dimitrios"]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.loc["PHELPS, Michael"]
# Out:
#                  Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# ...

# %% [markdown]
# range index is usually better for keeping a PK that's unique

# %%
summer.loc[["PHELPS, Michael", "LEWIS, Carl"], ["Medal", "Event"]]
# Out:
#                   Medal                   Event
# Athlete
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael  Bronze          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael  Bronze  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael    Gold          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael    Gold  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael  Silver          200M Butterfly
# ...

# %%
summer.loc[:, ["Medal", "Event"]]
# Out:
#                             Medal                       Event
# Athlete
# HAJOS, Alfred                Gold              100M Freestyle
# HERSCHMANN, Otto           Silver              100M Freestyle
# DRIVAS, Dimitrios          Bronze  100M Freestyle For Sailors
# MALOKINIS, Ioannis           Gold  100M Freestyle For Sailors
# CHASAPIS, Spiridon         Silver  100M Freestyle For Sailors
# ...                           ...                         ...
# JANIKOWSKI, Damian         Bronze                    Wg 84 KG
# REZAEI, Ghasem Gholamreza    Gold                    Wg 96 KG
# TOTROV, Rustam             Silver                    Wg 96 KG
# ALEKSANYAN, Artur          Bronze                    Wg 96 KG
# LIDBERG, Jimmy             Bronze                    Wg 96 KG
#
# [31165 rows x 2 columns]

# %%
summer.head(10)
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens  Aquatics   Swimming     AUT    Men
#
#                                             Event   Medal
# Athlete
# HAJOS, Alfred                      100M Freestyle    Gold
# ...

# %%
summer.loc[:"CHASAPIS, Spiridon"]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %% [markdown]
# With iloc, left boundary is included and right boundary excluded.

# %% [markdown]
# With loc, left AND right boundary is included.

# %% [markdown]
# summer.loc[:"PHELPS, Michael"] would not work because PHELPS... is not unique for slicing

# %%
summer.head(20)
# Out:
#                        Year    City      Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens   Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens   Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens   Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens   Aquatics   Swimming     AUT    Men
# PEPANOS, Antonios      1896  Athens   Aquatics   Swimming     GRE    Men
# LANE, Francis          1896  Athens  Athletics  Athletics     USA    Men
# ...

# %%
summer.loc["DRIVAS, Dimitrios":"BLAKE, Arthur"]
# Out:
#                        Year    City      Sport Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios      1896  Athens   Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens   Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens   Aquatics   Swimming     AUT    Men
# PEPANOS, Antonios      1896  Athens   Aquatics   Swimming     GRE    Men
# LANE, Francis          1896  Athens  Athletics  Athletics     USA    Men
# SZOKOLYI, Alajos       1896  Athens  Athletics  Athletics     HUN    Men
# BURKE, Thomas          1896  Athens  Athletics  Athletics     USA    Men
# ...

# %%
summer.loc["DRIVAS, Dimitrios":"BLAKE, Arthur", "City":"Discipline"]
# Out:
#                          City      Sport Discipline
# Athlete
# DRIVAS, Dimitrios      Athens   Aquatics   Swimming
# MALOKINIS, Ioannis     Athens   Aquatics   Swimming
# CHASAPIS, Spiridon     Athens   Aquatics   Swimming
# CHOROPHAS, Efstathios  Athens   Aquatics   Swimming
# HAJOS, Alfred          Athens   Aquatics   Swimming
# ANDREOU, Joannis       Athens   Aquatics   Swimming
# CHOROPHAS, Efstathios  Athens   Aquatics   Swimming
# NEUMANN, Paul          Athens   Aquatics   Swimming
# PEPANOS, Antonios      Athens   Aquatics   Swimming
# LANE, Francis          Athens  Athletics  Athletics
# SZOKOLYI, Alajos       Athens  Athletics  Athletics
# BURKE, Thomas          Athens  Athletics  Athletics
# HOFMANN, Fritz         Athens  Athletics  Athletics
# CURTIS, Thomas         Athens  Athletics  Athletics
# GOULDING, Grantley     Athens  Athletics  Athletics
# LERMUSIAUX, Albin      Athens  Athletics  Athletics
# FLACK, Edwin           Athens  Athletics  Athletics
# ...

# %% [markdown]
# ## Indexing and Slicing with reindex()

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer = pd.read_csv("summer.csv")

# %%
summer.loc[[0, 5, 30000], ["Athlete", "Medal"]]
# Out:
#                      Athlete   Medal
# 0              HAJOS, Alfred    Gold
# 5      CHOROPHAS, Efstathios  Bronze
# 30000       PAUTARAN, Maryna  Bronze

# %%
summer.reindex(index = [0, 5, 30000, 40000], columns = ["Athlete", "Medal", "Age"])
# Out:
#                      Athlete   Medal  Age
# 0              HAJOS, Alfred    Gold  NaN
# 5      CHOROPHAS, Efstathios  Bronze  NaN
# 30000       PAUTARAN, Maryna  Bronze  NaN
# 40000                    NaN     NaN  NaN

# %% [markdown]
# This does not work if you do not have a unique index

# %%
summer.iloc[10:21]
# Out:
#     Year    City      Sport Discipline             Athlete Country Gender  \
# 10  1896  Athens   Aquatics   Swimming   PEPANOS, Antonios     GRE    Men
# 11  1896  Athens  Athletics  Athletics       LANE, Francis     USA    Men
# 12  1896  Athens  Athletics  Athletics    SZOKOLYI, Alajos     HUN    Men
# 13  1896  Athens  Athletics  Athletics       BURKE, Thomas     USA    Men
# 14  1896  Athens  Athletics  Athletics      HOFMANN, Fritz     GER    Men
# 15  1896  Athens  Athletics  Athletics      CURTIS, Thomas     USA    Men
# 16  1896  Athens  Athletics  Athletics  GOULDING, Grantley     GBR    Men
# 17  1896  Athens  Athletics  Athletics   LERMUSIAUX, Albin     FRA    Men
# 18  1896  Athens  Athletics  Athletics        FLACK, Edwin     AUS    Men
# 19  1896  Athens  Athletics  Athletics       BLAKE, Arthur     USA    Men
# 20  1896  Athens  Athletics  Athletics     GMELIN, Charles     GBR    Men
#
#              Event   Medal
# 10  400M Freestyle  Silver
# ...

# %%
summer = pd.read_csv("summer.csv", index_col="Athlete")

# %%
summer.loc["LEWIS, Carl"]
# Out:
#              Year         City      Sport Discipline Country Gender  \
# Athlete
# LEWIS, Carl  1984  Los Angeles  Athletics  Athletics     USA    Men
# LEWIS, Carl  1984  Los Angeles  Athletics  Athletics     USA    Men
# LEWIS, Carl  1984  Los Angeles  Athletics  Athletics     USA    Men
# LEWIS, Carl  1984  Los Angeles  Athletics  Athletics     USA    Men
# LEWIS, Carl  1988        Seoul  Athletics  Athletics     USA    Men
# LEWIS, Carl  1988        Seoul  Athletics  Athletics     USA    Men
# LEWIS, Carl  1988        Seoul  Athletics  Athletics     USA    Men
# LEWIS, Carl  1992    Barcelona  Athletics  Athletics     USA    Men
# LEWIS, Carl  1992    Barcelona  Athletics  Athletics     USA    Men
# LEWIS, Carl  1996      Atlanta  Athletics  Athletics     USA    Men
#
#                     Event   Medal
# Athlete
# LEWIS, Carl          100M    Gold
# LEWIS, Carl          200M    Gold
# LEWIS, Carl  4X100M Relay    Gold
# LEWIS, Carl     Long Jump    Gold
# ...

# %%
summer.loc["LEWIS, Carl", ["Year", "Event", "Medal"]]
# Out:
#              Year         Event   Medal
# Athlete
# LEWIS, Carl  1984          100M    Gold
# LEWIS, Carl  1984          200M    Gold
# LEWIS, Carl  1984  4X100M Relay    Gold
# LEWIS, Carl  1984     Long Jump    Gold
# LEWIS, Carl  1988          100M    Gold
# LEWIS, Carl  1988          200M  Silver
# LEWIS, Carl  1988     Long Jump    Gold
# LEWIS, Carl  1992  4X100M Relay    Gold
# LEWIS, Carl  1992     Long Jump    Gold
# LEWIS, Carl  1996     Long Jump    Gold

# %% [markdown]
# This is best practice ^

# %%
type(summer)
# Out:
# pandas.core.frame.DataFrame

# %%
summer["Year"]
# Out:
# Athlete
# HAJOS, Alfred                1896
# HERSCHMANN, Otto             1896
# DRIVAS, Dimitrios            1896
# MALOKINIS, Ioannis           1896
# CHASAPIS, Spiridon           1896
#                              ...
# JANIKOWSKI, Damian           2012
# REZAEI, Ghasem Gholamreza    2012
# TOTROV, Rustam               2012
# ALEKSANYAN, Artur            2012
# LIDBERG, Jimmy               2012
# Name: Year, Length: 31165, dtype: int64

# %%
type(summer["Year"])
# Out:
# pandas.core.series.Series

# %%
summer.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Country', 'Gender', 'Event',
#        'Medal'],
#       dtype='object')

# %%
type(summer.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
summer.index
# Out:
# Index(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#        'MALOKINIS, Ioannis', 'CHASAPIS, Spiridon', 'CHOROPHAS, Efstathios',
#        'HAJOS, Alfred', 'ANDREOU, Joannis', 'CHOROPHAS, Efstathios',
#        'NEUMANN, Paul',
#        ...
#        'AHMADOV, Emin', 'KAZAKEVIC, Aleksandr', 'KHUGAEV, Alan',
#        'EBRAHIM, Karam Mohamed Gaber', 'GAJIYEV, Danyal', 'JANIKOWSKI, Damian',
#        'REZAEI, Ghasem Gholamreza', 'TOTROV, Rustam', 'ALEKSANYAN, Artur',
#        'LIDBERG, Jimmy'],
#       dtype='object', name='Athlete', length=31165)

# %%
type(summer.index)
# Out:
# pandas.core.indexes.base.Index
